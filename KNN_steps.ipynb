# %%
step-01 : read_csv file 
                - pd.read_csv("file_name")

step-02 : heck null value 
                - df.isna().sum()

step-03 : data Preprocessing 
                - remove unnesurry string data
                - df=pd.get_dummies(data=df,drop_first=True)

step-04 : define x & y
                - y predict column
                - x others all columns without y column name

step-05 : split data into train, test
                - from sklearn.model_selection import train_test_split
                  x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

step-06 : import KNeighborsClassifier
                - from sklearn.neighbors import KNeighborsClassifier
                  nn=KNeighborsClassifier(n_neighbors=25)

step-07 : model=nn.fit(x_train,y_train)
          y_pred=model.predict(x_test)
          y_pred

STEP-08 : from sklearn.metrics import confusion_matrix
          cm=confusion_matrix(y_pred,y_test)
          cm

step-09 : TN=cm[0][0]
          FP=cm[0][1]
          FN=cm[1][0]
          TP=cm[1][1]
step-10 : 
                -print("Accuracy    : ", (TP+TN) / (TP+TN+FP+FN))
                -print("Error_rate  : ", (FP+FN) / (TP+TN+FP+FN))
                -print("Sensitivity : ", TP / (TP+FN))
                -print("Speciticity : ", TN / (TN+FP))
