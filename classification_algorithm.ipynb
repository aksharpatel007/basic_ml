# %% [markdown]
# classification algorithm  -------> KNN (K-Nearest Neiohbors)
#                             |
#                             |----> Decision Tree

# %% [markdown]
# KNN (K-Nearest Neiohbors)

# %%
 --> specific category maa data devide kare(like yes or no) 
 --> k ni value odd complsory levani karne ke accurate answer prdict kari sakaie 
 --> k ti nearest data hoy tane based upar ti prdicat kari sakie
 --> formula (((x2-x1)^2)+((y2-y1)^2))^(1/2)

# %% [markdown]
# # Offline most imp program

# %%
MI VS RCB

 [1] TP - 3
 [2] TN - 2
 [3] FP - 2
 [4] FN - 2

predicted | actual   |        | 
-------------------------------
win       | win      |   TP     
win       | loss     |   FP
loss      | win      |   FN
loss      | loss     |   TN
win       | loss     |   FP
loss      | win      |   FN
win       | win      |   TP
loss      | loss     |   TN
win       | win      |   TP

|----------------------|
|  actual  |  Predicted  |
| |        |  NO  | YES  |
| *  | NO  |  TN  |  FP  |
|    | YES |  FN  |  TP  |

cm = [[TN,FP],[FN,TP]]
cm[0][0]
cm[0][1]
cm[1][0]
cm[1][1]

                (TP+TN)
Accuracy =  ----------------
              TP+TN+FP+FN

                FP+FN
Error rate = --------------
              TP+TN+FP+FN

                    TP
Sensitivity = --------------
                  TP+FN

                  TN 
Speciticity = ----------
                TN+FP
